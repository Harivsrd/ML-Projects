# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('housing.csv')
data.head()
# Out:
#    Area  Bedrooms  Age    Price
# 0  1200         2   10  3000000
# 1  1500         3    5  4500000
# 2  1000         2   15  2500000
# 3  1800         3    8  5000000
# 4  2000         4    2  6500000

# %%
# Area
# Bedrooms
# Age

# %%
x  = data[['Age','Bedrooms','Age']]
y = data['Price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict([[1600,3,5]])
print("Predicted Price:", prediction)
# Out:
# Predicted Price: [-70100000.0000067]
# c:\Users\Asus\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
score = model.score(x_test,y_test)
print("Model Accuracy:",score)
# Out:
# Model Accuracy: 0.8039830834294506

# %%
plt.scatter(data['Area'],data['Price'])
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()
